# %%
import pandas as pd
import nibabel as nib
import numpy as np
import os
from dice import dice

from utils import organizeFolders, organizeFiles, openImage

# %%
# Main Folder Dir
fp = '/data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/'
splitter = '/'

# Pandas dataframe to store everything
"""
Shorthand meanings
    - 'vol' = original image volume
    - 'GT' = ground truth segmentation
    - 'MS' = Manual Segmentation
    - 'SC' = Smart Click Segmentation
    - 'LS' = Level Set Segmentation
"""

df = pd.DataFrame(columns=[
    # Patient ID
    'patient_id',

    # Voxel Count
    'vol_voxCnt',
    'GT_voxCnt',
    'MS_voxCnt',
    'LS_voxCnt',

    # Dice Score
    'GT-MS_dice',
    'GT-LS_dice',
    'MS_LS_dice',
])

# Maping file names to respective categories
file_map = {
    'vol' : 'dicom_vol',
    'LM' : 'pred_vol',
    'GT' : 'GT_liver_cyst_vol',
    'MS' : 'DR_liver_cyst_vol',
    'LS' : 'CL_liver_cyst_level_set_vol'}

inv_file_map = {v: k for k, v in file_map.items()}

# %%
from difflib import SequenceMatcher

def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

def findIndex(file_map, a):
    best_choice = None
    best_score = 0.8
    for k, v in file_map.items():
        if similar(a, k) > best_score:
            best_choice = similar(a, k)
            best_choice = k

    return best_choice, best_score

# %%
df = pd.DataFrame()

# Get folder paths
folder_dir = organizeFolders(fp)

# Get file paths and info
for i in folder_dir:
    # Get File Paths
    file_dir = organizeFiles(i)
    patient_id = i.split(splitter)[-1]

    # Organize all numpy arrays into dictionary following the file_map
    np_files = {}
    np_files_vol = {}

    for j in file_dir:
        np_arr, volume = openImage(j)
        try:
            np_files[ inv_file_map[j.split(splitter)[-1].split('.nii')[0]] ] = np_arr
            np_files_vol[ inv_file_map[j.split(splitter)[-1].split('.nii')[0]] ] = volume
        except:
            print('Error: ', j)

            index, score = findIndex(inv_file_map, j.split(splitter)[-1].split('.nii')[0])
            if index is not None and inv_file_map[index] not in np_files.keys():
                print('Found replacement for', j, 'with', index, 'with score of', score)
                np_files[ inv_file_map[index] ] = np_arr
                np_files_vol[ inv_file_map[index] ] = volume

            pass


    print(patient_id, '---', np_files_vol)

    # Start geting information
    ## voxCnt and volume

    temp = {}
    keyword = '_voxCnt'
    keyword2 = '_volume(in cm^3)'
    for k in np_files.keys():
        temp['patient_id'] = patient_id
        if k == 'vol':
            temp[k+keyword] = round(np_files[k].shape[0] * np_files[k].shape[1] * np_files[k].shape[2])
            temp[k+keyword2] = round(np_files_vol[k] * temp[k+keyword], 6)
        else:
            temp[k+keyword] = round(np_files[k].sum())
            temp[k+keyword2] = round(np_files_vol[k] * temp[k+keyword], 6)

    # Dice Score
    try:
#         temp['GT-MS_dice'] = dice(np_files['GT'], np_files['MS']) # Ground Truth - Manual Segmentation
#         temp['GT-SC_dice'] = dice(np_files['GT'], np_files['SC']) # Ground Truth - Smart Click Segmentation
        temp['MS_SC_dice'] = dice(np_files['MS'], np_files['LS']) # Manual Segmentation - Smart Click Segmentation
    except:
        pass


    df = df.append(pd.Series(temp, name=patient_id), ignore_index=True)
# Out:
# DEBUG: list directories - ['WC-IRB1308014251_071', 'WC-IRB1308014251_059', 'WC-IRB1308014251_042', 'WC-IRB1308014251_004', 'WC-IRB1308014251_055', 'WC-IRB1308014251_001', 'WC-IRB1308014251_016', 'WC-IRB1308014251_039_Visit2', 'WC-IRB1308014251_003', 'WC-IRB1308014251_061', 'WC-IRB1308014251_040', 'WC-IRB1308014251_006', 'WC-IRB1308014251_032', 'WC-IRB1308014251_025', 'WC-IRB1308014251_066_Visit2', 'WC-IRB1308014251_015', 'WC-IRB1308014251_011', 'WC-IRB1308014251_031', 'WC-IRB1308014251_030', 'WC-IRB1308014251_018', 'WC-IRB1308014251_024_Visit2', 'WC-IRB1308014251_026', 'WC-IRB1308014251_082_Visit2', 'WC-IRB1308014251_034', 'WC-IRB1308014251_051', 'WC-IRB1308014251_005', 'WC-IRB1308014251_017', 'WC-IRB1308014251_039_Visit1', 'WC-IRB1308014251_020', 'WC-IRB1308014251_033', 'WC-IRB1308014251_066_Visit1', 'WC-IRB1308014251_058', 'WC-IRB1308014251_057', 'WC-IRB1308014251_007', 'WC-IRB1308014251_046', 'WC-IRB1308014251_083_Visit2', 'WC-IRB1308014251_035', 'WC-IRB1308014251_044', 'WC-IRB1308014251_008', 'WC-IRB1308014251_082_Visit1']
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_071/pred_vol.nii.gz
# WC-IRB1308014251_071 --- {'vol': 0.67734375, 'LS': 0.67734375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_059/pred_vol.nii.gz
# WC-IRB1308014251_059 --- {'vol': 0.8461073875427246, 'LS': 0.8461073875427246}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_042/pred_vol.nii.gz
# WC-IRB1308014251_042 --- {'vol': 0.9375, 'LS': 0.9375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_004/pred_vol.nii.gz
# WC-IRB1308014251_004 --- {'vol': 1.9531587600708007, 'LS': 1.9531587600708007}
# WC-IRB1308014251_055 --- {}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_001/pred_vol.nii.gz
# WC-IRB1308014251_001 --- {'vol': 0.3052148580551147, 'LS': 0.3052148580551147}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_016/pred_vol.nii.gz
# WC-IRB1308014251_016 --- {'vol': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_039_Visit2/pred_vol.nii.gz
# WC-IRB1308014251_039_Visit2 --- {'vol': 0.759375, 'LS': 0.759375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_003/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_003/pred_vol.nii.gz
# WC-IRB1308014251_003 --- {'vol': 0.67734375, 'MS': 0.67734375, 'LS': 0.67734375}
# WC-IRB1308014251_061 --- {}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_040/pred_vol.nii.gz
# WC-IRB1308014251_040 --- {'vol': 0.8460335731506348, 'LS': 0.8460335731506348}
# WC-IRB1308014251_006 --- {}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_032/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_032/pred_vol.nii.gz
# WC-IRB1308014251_032 --- {'vol': 0.2471752405166626, 'MS': 0.2471752405166626, 'LS': 0.2471752405166626}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_025/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_025/pred_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_025/25.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_025/dicom_volyo.nii.gz
# WC-IRB1308014251_025 --- {'vol': 1.0986714363098145, 'MS': 1.0986714363098145, 'LS': 1.0986714363098145}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_066_Visit2/pred_vol.nii.gz
# WC-IRB1308014251_066_Visit2 --- {'vol': 0.29660978317260744, 'LS': 0.29660978317260744}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_015/pred_vol.nii.gz
# WC-IRB1308014251_015 --- {'vol': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_011/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_011/roughLiverSeg.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_011/pred_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_011/roughtLiverLesionSeg.nii
# WC-IRB1308014251_011 --- {'vol': 1.8566349029541016, 'MS': 1.8566349029541016, 'LS': 1.8566349029541016}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_031/pred_vol.nii.gz
# WC-IRB1308014251_031 --- {'vol': 0.759375, 'LS': 0.759375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_030/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_030/pred_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_030/DR_liver_lesion_hang_click_vol.nii.gz
# WC-IRB1308014251_030 --- {'vol': 0.84609375, 'MS': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_018/pred_vol.nii.gz
# WC-IRB1308014251_018 --- {'vol': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_024_Visit2/DR_liver_cyst_smart_click_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_024_Visit2/pred_vol.nii.gz
# WC-IRB1308014251_024_Visit2 --- {'vol': 0.67734375, 'MS': 0.67734375, 'LS': 0.67734375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_026/pred_vol.nii.gz
# WC-IRB1308014251_026 --- {'vol': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_082_Visit2/pred_vol.nii.gz
# WC-IRB1308014251_082_Visit2 --- {'vol': 0.9375, 'LS': 0.9375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_034/DR_liver_cyst_smart_click_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_034/pred_vol.nii.gz
# WC-IRB1308014251_034 --- {'vol': 0.8459912300109863, 'MS': 0.8459912300109863, 'LS': 0.8459912300109863}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_051/pred_vol.nii.gz
# WC-IRB1308014251_051 --- {'vol': 0.8461435317993165, 'LS': 0.8461435317993165}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_005/pred_vol.nii.gz
# WC-IRB1308014251_005 --- {'vol': 1.08347749710083, 'LS': 1.08347749710083}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_017/pred_vol.nii.gz
# WC-IRB1308014251_017 --- {'vol': 0.33051652908325196, 'LS': 0.33051652908325196}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_039_Visit1/DR_liver_cyst_smart_click1.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_039_Visit1/pred_vol.nii.gz
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_039_Visit1/DR_liver_cyst_smart_click_vol.nii.nii
# WC-IRB1308014251_039_Visit1 --- {'MS': 1.9531600952148438, 'vol': 1.9531600952148438, 'LS': 1.9531600952148438}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_020/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_020/pred_vol.nii.gz
# WC-IRB1308014251_020 --- {'vol': 1.134375, 'MS': 1.134375, 'LS': 1.134375}
# WC-IRB1308014251_033 --- {}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_066_Visit1/pred_vol.nii.gz
# WC-IRB1308014251_066_Visit1 --- {'vol': 1.6711423873901368, 'LS': 1.6711423873901368}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_058/pred_vol.nii.gz
# WC-IRB1308014251_058 --- {'vol': 0.8460517883300781, 'LS': 0.8460517883300781}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_057/pred_vol.nii.gz
# WC-IRB1308014251_057 --- {'vol': 0.67734375, 'LS': 0.67734375}
# WC-IRB1308014251_007 --- {}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_046/pred_vol.nii.gz
# WC-IRB1308014251_046 --- {'vol': 1.03359375, 'LS': 1.03359375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_083_Visit2/pred_vol.nii.gz
# WC-IRB1308014251_083_Visit2 --- {'vol': 0.84609375, 'LS': 0.84609375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_035/pred_vol.nii.gz
# WC-IRB1308014251_035 --- {'vol': 1.134375, 'LS': 1.134375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_044/pred_vol.nii.gz
# WC-IRB1308014251_044 --- {'vol': 0.19531239271163942, 'LS': 0.19531239271163942}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_008/DR_liver_cyst_smart_click_vol.nii
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_008/pred_vol.nii.gz
# WC-IRB1308014251_008 --- {'vol': 0.9375, 'MS': 0.9375, 'LS': 0.9375}
# Error:  /data/Collin/Liver_Tumor_Segmentation_Methods/ISMRM_AutoLevelSet/WC-IRB1308014251_082_Visit1/pred_vol.nii.gz
# WC-IRB1308014251_082_Visit1 --- {'vol': 0.846094799041748, 'LS': 0.846094799041748}

# %%
df
# Out:
#     LS_volume(in cm^3)  LS_voxCnt                   patient_id  \
# 0        236861.013281   349691.0         WC-IRB1308014251_071
# 1         37422.483644    44229.0         WC-IRB1308014251_059
# 2         57423.750000    61252.0         WC-IRB1308014251_042
# 3          9103.672981     4661.0         WC-IRB1308014251_004
# 4                  NaN        NaN                          NaN
# 5         38553.520010   126316.0         WC-IRB1308014251_001
# 6          3603.513281     4259.0         WC-IRB1308014251_016
# 7         38875.443750    51194.0  WC-IRB1308014251_039_Visit2
# 8          2433.018750     3592.0         WC-IRB1308014251_003
# 9                  NaN        NaN                          NaN
# 10         7304.653871     8634.0         WC-IRB1308014251_040
# 11                 NaN        NaN                          NaN
# 12        14207.880000    57481.0         WC-IRB1308014251_032
# 13        26958.101033    24537.0         WC-IRB1308014251_025
# 14         8095.074202    27292.0  WC-IRB1308014251_066_Visit2
# 15         6375.316406     7535.0         WC-IRB1308014251_015
# 16       104112.658818    56076.0         WC-IRB1308014251_011
# 17        34441.453125    45355.0         WC-IRB1308014251_031
# 18         2967.250781     3507.0         WC-IRB1308014251_030
# 19        14299.830469    16901.0         WC-IRB1308014251_018
# 20         8920.617188    13170.0  WC-IRB1308014251_024_Visit2
# 21         9562.551562    11302.0         WC-IRB1308014251_026
# 22         3765.000000     4016.0  WC-IRB1308014251_082_Visit2
# 23         7411.729166     8761.0         WC-IRB1308014251_034
# 24        20342.982792    24042.0         WC-IRB1308014251_051
# 25        71375.163599    65876.0         WC-IRB1308014251_005
# 26          648.803947     1963.0         WC-IRB1308014251_017
# 27        19123.390492     9791.0  WC-IRB1308014251_039_Visit1
# 28         2916.478125     2571.0         WC-IRB1308014251_020
# 29                 NaN        NaN                          NaN
# 30        33833.948775    20246.0  WC-IRB1308014251_066_Visit1
# 31         1209.854057     1430.0         WC-IRB1308014251_058
# 32         6688.769531     9875.0         WC-IRB1308014251_057
# 33                 NaN        NaN                          NaN
# 34         2407.239844     2329.0         WC-IRB1308014251_046
# 35         6611.376562     7814.0  WC-IRB1308014251_083_Visit2
# 36          473.034375      417.0         WC-IRB1308014251_035
# 37        17372.256082    88946.0         WC-IRB1308014251_044
# 38        24304.687500    25925.0         WC-IRB1308014251_008
# 39          875.708117     1035.0  WC-IRB1308014251_082_Visit1
#
#     vol_volume(in cm^3)  vol_voxCnt  MS_SC_dice  MS_volume(in cm^3)  MS_voxCnt
# 0          4.508400e+06   6656000.0         NaN                 NaN        NaN
# 1          4.938560e+06   5836800.0         NaN                 NaN        NaN
# 2          6.192000e+06   6604800.0         NaN                 NaN        NaN
# 3          9.472164e+06   4849664.0         NaN                 NaN        NaN
# 4                   NaN         NaN         NaN                 NaN        NaN
# 5          7.520963e+06  24641536.0         NaN                 NaN        NaN
# 6          5.198400e+06   6144000.0         NaN                 NaN        NaN
# 7          5.054400e+06   6656000.0         NaN                 NaN        NaN
# 8          4.282980e+06   6323200.0    0.540089         3970.589062     5862.0
# 9                   NaN         NaN         NaN                 NaN        NaN
# 10         4.678227e+06   5529600.0         NaN                 NaN        NaN
# 11                  NaN         NaN         NaN                 NaN        NaN
# 12         6.479551e+06  26214400.0    0.403233        10255.053554    41489.0
# 13         2.232078e+06   2031616.0    0.591767        14466.206802    13167.0
# 14         3.421197e+06  11534336.0         NaN                 NaN        NaN
# 15         4.938480e+06   5836800.0         NaN                 NaN        NaN
# 16         8.273997e+06   4456448.0    0.747855       138076.081098    74369.0
# 17         3.265920e+06   4300800.0         NaN                 NaN        NaN
# 18         4.678560e+06   5529600.0    0.447616         6400.699219     7565.0
# 19         5.328360e+06   6297600.0         NaN                 NaN        NaN
# 20         3.944850e+06   5824000.0    0.538015        12914.913281    19067.0
# 21         4.678560e+06   5529600.0         NaN                 NaN        NaN
# 22         5.772000e+06   6156800.0         NaN                 NaN        NaN
# 23         5.457659e+06   6451200.0    0.573158         9084.253828    10738.0
# 24         4.548868e+06   5376000.0         NaN                 NaN        NaN
# 25         6.823308e+06   6297600.0         NaN                 NaN        NaN
# 26         2.495316e+07  75497472.0         NaN                 NaN        NaN
# 27         6.912124e+06   3538944.0    0.108162         4351.640692     2228.0
# 28         6.272640e+06   5529600.0    0.363433        12309.103125    10851.0
# 29                  NaN         NaN         NaN                 NaN        NaN
# 30         6.023599e+06   3604480.0         NaN                 NaN        NaN
# 31         3.118885e+06   3686400.0         NaN                 NaN        NaN
# 32         4.265640e+06   6297600.0         NaN                 NaN        NaN
# 33                  NaN         NaN         NaN                 NaN        NaN
# 34         8.890560e+06   8601600.0         NaN                 NaN        NaN
# 35         4.808520e+06   5683200.0         NaN                 NaN        NaN
# 36         6.272640e+06   5529600.0         NaN                 NaN        NaN
# 37         4.505598e+06  23068672.0         NaN                 NaN        NaN
# 38         5.184000e+06   5529600.0    0.378218        49536.562500    52839.0
# 39         2.859124e+06   3379200.0         NaN                 NaN        NaN

# %%
df
# Out:
#   patient_id  vol_voxCnt  vol_volume(in cm^3)  SC_voxCnt  SC_volume(in cm^3)  \
# 0          1   4456448.0            8273996.9    71072.0       131954.755823
#
#    MS_voxCnt  MS_volume(in cm^3)  GT_voxCnt  GT_volume(in cm^3)  MS_SC_dice
# 0    74369.0       138076.081098    74556.0       138423.271825    0.976465

# %%
df.to_csv('dice_score.csv')
